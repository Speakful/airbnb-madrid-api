# %%
import requests

root_path = "https://online-ds-bridge-proyects-arielaastorga.onrender.com"
path = "/predict_query"

params = {
    "neighbourhood_cleansed": "Sol",
    "room_type": "Entire home/apt",
    "accommodates": 2,
    "bathrooms": 1,
    "bedrooms": 1,
    "beds": 1,
    "price": 120,
    "minimum_nights": 5,
    "number_of_reviews": 173,
    "review_scores_rating": 4.8,
    "availability_365": 342
}

response = requests.get(url=root_path + path, params=params)

print(response)
print(response.text)
print(response.json())
# Out:
# <Response [200]>
# {"input":{"availability_365":342.0,"minimum_nights":5.0,"neighbourhood":"Sol","number_of_reviews":173.0,"number_of_reviews_ltm":1.0,"room_type":"Entire home/apt"},"predicted_price":192.38}
#
# {'input': {'availability_365': 342.0, 'minimum_nights': 5.0, 'neighbourhood': 'Sol', 'number_of_reviews': 173.0, 'number_of_reviews_ltm': 1.0, 'room_type': 'Entire home/apt'}, 'predicted_price': 192.38}

# %%
#EJEMPLO POST

import requests

root_path = "https://online-ds-bridge-proyects-arielaastorga.onrender.com"
path = "/predict"

content = {
    "neighbourhood_cleansed": "Sol",
    "room_type": "Entire home/apt",
    "accommodates": 2,
    "bathrooms": 1,
    "bedrooms": 1,
    "beds": 1,
    "price": 120,
    "minimum_nights": 5,
    "number_of_reviews": 173,
    "review_scores_rating": 4.8,
    "availability_365": 342
}

response = requests.post(url=root_path + path, json=content)

print(response)
print(response.text)
print(response.json())
# Out:
# <Response [200]>
# {"input":{"availability_365":342,"minimum_nights":5,"neighbourhood":"Sol","number_of_reviews":173,"number_of_reviews_ltm":1,"room_type":"Entire home/apt"},"predicted_price":192.38}
#
# {'input': {'availability_365': 342, 'minimum_nights': 5, 'neighbourhood': 'Sol', 'number_of_reviews': 173, 'number_of_reviews_ltm': 1, 'room_type': 'Entire home/apt'}, 'predicted_price': 192.38}
